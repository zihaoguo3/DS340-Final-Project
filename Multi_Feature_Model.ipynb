# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import tensorflow as tf

# %%
# Load & Preprocess the data
df = pd.read_csv('age_gender.csv')
df = df.dropna()
df = df.drop ('img_name', axis = 1)
df.head()
# Out:
#    age  ethnicity  gender                                             pixels
# 0    1          2       0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1    1          2       0  164 74 111 168 169 171 175 182 184 188 193 199...
# 2    1          2       0  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3    1          2       0  193 197 198 200 199 200 202 203 204 205 208 21...
# 4    1          2       0  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
# Transform pixel to (48, 48, 1)
X = df['pixels'].apply(lambda x: np.array(list(map(int, x.split(' ')))))
X = np.stack(X, axis=0)
X = X.reshape(-1, 48, 48, 1)
X = X / 255.0

# %%
# Image Visualization Check
fig,axes = plt.subplots(1, 5, figsize=(20, 20))
for i in range(5):
    axes[i].imshow(X[i, :, :, 0], cmap='gray')
    axes[i].axis('off')
    axes[i].set_title(f'Image {i+1}')
plt.show()

# %%
# Normalize age to 0 - 1
# Gender to 2 classes
# Ethnicity to 5 classes

y_age = df['age'].astype('float32')
y_gender = to_categorical(df['gender'], num_classes = 2)
y_ethnicity = to_categorical(df['ethnicity'], num_classes = 5)

# %%
# Train & Test sets
X_train, X_test, y_age_train, y_age_test, y_gender_train, y_gender_test, y_eth_train, y_eth_test = train_test_split(
    X, y_age, y_gender, y_ethnicity,
    test_size=0.2,
    random_state=42
)

# %%
#CNN
def ConvFunc(x, filters=32, kernel_size=(3, 3), dropout_rate=0.1):
    x = Conv2D(
        filters,
        kernel_size=kernel_size,
        padding="same",
        kernel_initializer="he_normal",
        kernel_regularizer=l2(0.001)
    )(x)

    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPooling2D()(x)
    x = Dropout(dropout_rate)(x)
    return x

# %%
from tensorflow.keras.layers import Activation
def swish(x):
    return x * tf.nn.sigmoid(x)

# %%
#Multi-feature Model
def build_multi_feature_model():
    inputs = Input(shape=(48, 48, 1))

    #Convolutional Layers
    x = ConvFunc(inputs, 32, dropout_rate=0.1)
    x = ConvFunc(x, 64, dropout_rate=0.15)
    x = ConvFunc(x, 128, dropout_rate=0.2)
    x = ConvFunc(x, 256, dropout_rate=0.25)
    x = Flatten()(x)

    #Age
    age_branch = Dense(256)(x)
    age_branch = Activation(swish)(age_branch)
    age_branch = Dropout(0.4)(age_branch)
    age_output = Dense(1, activation="softplus", name = 'age_output')(age_branch)

    #Gender
    gender_branch = Dense(256, activation="relu")(x)
    gender_branch = Dropout(0.4)(gender_branch)
    gender_output = Dense(2, activation="softmax", name = 'gender_output')(gender_branch)

    #Ethnicity
    ethnicity_branch = Dense(256, activation="relu")(x)
    ethnicity_branch = Dropout(0.4)(ethnicity_branch)
    ethnicity_output = Dense(5, activation="softmax", name = 'ethnicity_output')(ethnicity_branch)

    model = Model(inputs, [age_output, gender_output, ethnicity_output])
    return model

multi_feature_model = build_multi_feature_model()

# %%
# Compile Model
multi_feature_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002),
    loss={
        'age_output': tf.keras.losses.Huber(delta=2.0),
        'gender_output': tf.keras.losses.BinaryCrossentropy(),
        'ethnicity_output': tf.keras.losses.CategoricalCrossentropy()
    },
    loss_weights={
        'age_output': 1.5,
        'gender_output': 1,
        'ethnicity_output': 2
    },
    metrics={
        'age_output': 'mae',
        'gender_output': 'accuracy',
        'ethnicity_output': 'accuracy'
    }
)
multi_feature_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 48, 48, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 48, 48,    │        320 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 48,    │        128 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 24, 24,    │          0 │ activation_10[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 24, 24,    │          0 │ max_pooling2d_8[… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 24, 24,    │     18,496 │ dropout_14[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 24,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 24, 24,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 12, 12,    │          0 │ activation_11[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 12, 12,    │          0 │ max_pooling2d_9[… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 12, 12,    │     73,856 │ dropout_15[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 12,    │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 12, 12,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_10    │ (None, 6, 6, 128) │          0 │ activation_12[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 6, 6, 128) │          0 │ max_pooling2d_10… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 6, 6, 256) │    295,168 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 256) │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 6, 6, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_11    │ (None, 3, 3, 256) │          0 │ activation_13[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 3, 3, 256) │          0 │ max_pooling2d_11… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 2304)      │          0 │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │    590,080 │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 256)       │          0 │ dense_6[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 256)       │    590,080 │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 256)       │    590,080 │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 256)       │          0 │ activation_14[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 256)       │          0 │ dense_7[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 256)       │          0 │ dense_8[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │        257 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_output       │ (None, 2)         │        514 │ dropout_19[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ethnicity_output    │ (None, 5)         │      1,285 │ dropout_20[0][0]  │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,162,056 (8.25 MB)
#  Trainable params: 2,161,096 (8.24 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
#Training
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True, verbose=1
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss", patience=5, verbose=1, factor=0.5, min_lr=1e-5
)

multi_feature_model.fit(
    X_train,
    {
        'age_output': y_age_train,
        'gender_output': y_gender_train,
        'ethnicity_output': y_eth_train
    },
    validation_data=(
        X_test,
        {
            'age_output': y_age_test,
            'gender_output': y_gender_test,
            'ethnicity_output': y_eth_test
        }
    ),
    batch_size=128,
    epochs=100,
    callbacks=[early_stopping, lr_scheduler],
    verbose=1
)
# Out:
# Epoch 1/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 28s 88ms/step - age_output_loss: 31.9209 - age_output_mae: 16.9254 - ethnicity_output_accuracy: 0.3821 - ethnicity_output_loss: 1.8962 - gender_output_accuracy: 0.6150 - gender_output_loss: 0.7375 - loss: 53.3703 - val_age_output_loss: 33.1294 - val_age_output_mae: 17.4663 - val_ethnicity_output_accuracy: 0.4330 - val_ethnicity_output_loss: 1.4041 - val_gender_output_accuracy: 0.6575 - val_gender_output_loss: 0.6444 - val_loss: 53.8787 - learning_rate: 2.0000e-04
# Epoch 2/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 22.7361 - age_output_mae: 12.3264 - ethnicity_output_accuracy: 0.4790 - ethnicity_output_loss: 1.3320 - gender_output_accuracy: 0.7072 - gender_output_loss: 0.5775 - loss: 38.3025 - val_age_output_loss: 23.0889 - val_age_output_mae: 12.5083 - val_ethnicity_output_accuracy: 0.4813 - val_ethnicity_output_loss: 1.2284 - val_gender_output_accuracy: 0.7277 - val_gender_output_loss: 0.5621 - val_loss: 38.6741 - learning_rate: 2.0000e-04
# Epoch 3/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 19.5610 - age_output_mae: 10.7305 - ethnicity_output_accuracy: 0.5011 - ethnicity_output_loss: 1.2753 - gender_output_accuracy: 0.7359 - gender_output_loss: 0.5414 - loss: 33.3916 - val_age_output_loss: 20.2818 - val_age_output_mae: 11.0969 - val_ethnicity_output_accuracy: 0.5412 - val_ethnicity_output_loss: 1.1524 - val_gender_output_accuracy: 0.7570 - val_gender_output_loss: 0.5099 - val_loss: 34.2237 - learning_rate: 2.0000e-04
# Epoch 4/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 17.5912 - age_output_mae: 9.7367 - ethnicity_output_accuracy: 0.5330 - ethnicity_output_loss: 1.2096 - gender_output_accuracy: 0.7475 - gender_output_loss: 0.5219 - loss: 30.2855 - val_age_output_loss: 16.6225 - val_age_output_mae: 9.3499 - val_ethnicity_output_accuracy: 0.5619 - val_ethnicity_output_loss: 1.1060 - val_gender_output_accuracy: 0.7724 - val_gender_output_loss: 0.4727 - val_loss: 28.8916 - learning_rate: 2.0000e-04
# Epoch 5/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 16.8491 - age_output_mae: 9.3650 - ethnicity_output_accuracy: 0.5365 - ethnicity_output_loss: 1.1969 - gender_output_accuracy: 0.7523 - gender_output_loss: 0.5102 - loss: 29.1334 - val_age_output_loss: 15.9086 - val_age_output_mae: 8.9547 - val_ethnicity_output_accuracy: 0.5868 - val_ethnicity_output_loss: 1.0624 - val_gender_output_accuracy: 0.7764 - val_gender_output_loss: 0.4620 - val_loss: 27.6113 - learning_rate: 2.0000e-04
# Epoch 6/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 16.2518 - age_output_mae: 9.0624 - ethnicity_output_accuracy: 0.5552 - ethnicity_output_loss: 1.1437 - gender_output_accuracy: 0.7560 - gender_output_loss: 0.4963 - loss: 28.1179 - val_age_output_loss: 18.8626 - val_age_output_mae: 10.4852 - val_ethnicity_output_accuracy: 0.5646 - val_ethnicity_output_loss: 1.1014 - val_gender_output_accuracy: 0.7878 - val_gender_output_loss: 0.4403 - val_loss: 32.2255 - learning_rate: 2.0000e-04
# Epoch 7/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 16.0333 - age_output_mae: 8.9558 - ethnicity_output_accuracy: 0.5675 - ethnicity_output_loss: 1.1283 - gender_output_accuracy: 0.7720 - gender_output_loss: 0.4819 - loss: 27.7433 - val_age_output_loss: 18.2251 - val_age_output_mae: 10.1451 - val_ethnicity_output_accuracy: 0.6011 - val_ethnicity_output_loss: 1.0165 - val_gender_output_accuracy: 0.7906 - val_gender_output_loss: 0.4325 - val_loss: 31.0334 - learning_rate: 2.0000e-04
# Epoch 8/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 15.5162 - age_output_mae: 8.6941 - ethnicity_output_accuracy: 0.5767 - ethnicity_output_loss: 1.1048 - gender_output_accuracy: 0.7772 - gender_output_loss: 0.4590 - loss: 26.8977 - val_age_output_loss: 15.6083 - val_age_output_mae: 8.7794 - val_ethnicity_output_accuracy: 0.6032 - val_ethnicity_output_loss: 1.0110 - val_gender_output_accuracy: 0.8024 - val_gender_output_loss: 0.4129 - val_loss: 26.9475 - learning_rate: 2.0000e-04
# Epoch 9/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 15.5403 - age_output_mae: 8.7105 - ethnicity_output_accuracy: 0.5911 - ethnicity_output_loss: 1.0859 - gender_output_accuracy: 0.7765 - gender_output_loss: 0.4646 - loss: 26.9014 - val_age_output_loss: 15.8725 - val_age_output_mae: 8.9237 - val_ethnicity_output_accuracy: 0.6349 - val_ethnicity_output_loss: 0.9552 - val_gender_output_accuracy: 0.7946 - val_gender_output_loss: 0.4275 - val_loss: 27.2607 - learning_rate: 2.0000e-04
# Epoch 10/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 14.9039 - age_output_mae: 8.3872 - ethnicity_output_accuracy: 0.6034 - ethnicity_output_loss: 1.0544 - gender_output_accuracy: 0.7846 - gender_output_loss: 0.4482 - loss: 25.8654 - val_age_output_loss: 19.8741 - val_age_output_mae: 10.9692 - val_ethnicity_output_accuracy: 0.6054 - val_ethnicity_output_loss: 1.0042 - val_gender_output_accuracy: 0.8045 - val_gender_output_loss: 0.4053 - val_loss: 33.4537 - learning_rate: 2.0000e-04
# Epoch 11/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 14.4515 - age_output_mae: 8.1593 - ethnicity_output_accuracy: 0.6108 - ethnicity_output_loss: 1.0288 - gender_output_accuracy: 0.7900 - gender_output_loss: 0.4415 - loss: 25.1295 - val_age_output_loss: 21.0242 - val_age_output_mae: 11.5635 - val_ethnicity_output_accuracy: 0.6222 - val_ethnicity_output_loss: 0.9640 - val_gender_output_accuracy: 0.8104 - val_gender_output_loss: 0.3969 - val_loss: 35.1244 - learning_rate: 2.0000e-04
# Epoch 12/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 14.1276 - age_output_mae: 7.9959 - ethnicity_output_accuracy: 0.6147 - ethnicity_output_loss: 1.0206 - gender_output_accuracy: 0.7928 - gender_output_loss: 0.4366 - loss: 24.6210 - val_age_output_loss: 15.8092 - val_age_output_mae: 8.9207 - val_ethnicity_output_accuracy: 0.6404 - val_ethnicity_output_loss: 0.9220 - val_gender_output_accuracy: 0.8100 - val_gender_output_loss: 0.3889 - val_loss: 27.1417 - learning_rate: 2.0000e-04
# Epoch 13/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 14.0263 - age_output_mae: 7.9445 - ethnicity_output_accuracy: 0.6204 - ethnicity_output_loss: 1.0103 - gender_output_accuracy: 0.7973 - gender_output_loss: 0.4334 - loss: 24.4451 - val_age_output_loss: 14.7130 - val_age_output_mae: 8.3473 - val_ethnicity_output_accuracy: 0.6644 - val_ethnicity_output_loss: 0.8742 - val_gender_output_accuracy: 0.8283 - val_gender_output_loss: 0.3755 - val_loss: 25.3288 - learning_rate: 2.0000e-04
# Epoch 14/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - age_output_loss: 14.2409 - age_output_mae: 8.0521 - ethnicity_output_accuracy: 0.6375 - ethnicity_output_loss: 0.9867 - gender_output_accuracy: 0.8000 - gender_output_loss: 0.4293 - loss: 24.7141 - val_age_output_loss: 19.3226 - val_age_output_mae: 10.6327 - val_ethnicity_output_accuracy: 0.6456 - val_ethnicity_output_loss: 0.9022 - val_gender_output_accuracy: 0.8038 - val_gender_output_loss: 0.4059 - val_loss: 32.2169 - learning_rate: 2.0000e-04
# Epoch 15/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 13.6787 - age_output_mae: 7.7711 - ethnicity_output_accuracy: 0.6436 - ethnicity_output_loss: 0.9683 - gender_output_accuracy: 0.8083 - gender_output_loss: 0.4145 - loss: 23.8185 - val_age_output_loss: 19.8724 - val_age_output_mae: 10.9120 - val_ethnicity_output_accuracy: 0.6583 - val_ethnicity_output_loss: 0.8668 - val_gender_output_accuracy: 0.8245 - val_gender_output_loss: 0.3685 - val_loss: 32.9520 - learning_rate: 2.0000e-04
# Epoch 16/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 13.5368 - age_output_mae: 7.7027 - ethnicity_output_accuracy: 0.6486 - ethnicity_output_loss: 0.9532 - gender_output_accuracy: 0.8059 - gender_output_loss: 0.4177 - loss: 23.5781 - val_age_output_loss: 17.7335 - val_age_output_mae: 9.7912 - val_ethnicity_output_accuracy: 0.6767 - val_ethnicity_output_loss: 0.8356 - val_gender_output_accuracy: 0.8308 - val_gender_output_loss: 0.3681 - val_loss: 29.5328 - learning_rate: 2.0000e-04
# Epoch 17/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 13.4713 - age_output_mae: 7.6670 - ethnicity_output_accuracy: 0.6452 - ethnicity_output_loss: 0.9554 - gender_output_accuracy: 0.8040 - gender_output_loss: 0.4146 - loss: 23.4811 - val_age_output_loss: 14.2849 - val_age_output_mae: 8.0867 - val_ethnicity_output_accuracy: 0.6691 - val_ethnicity_output_loss: 0.8486 - val_gender_output_accuracy: 0.8441 - val_gender_output_loss: 0.3536 - val_loss: 24.4718 - learning_rate: 2.0000e-04
# Epoch 18/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 13.4828 - age_output_mae: 7.6691 - ethnicity_output_accuracy: 0.6551 - ethnicity_output_loss: 0.9376 - gender_output_accuracy: 0.8058 - gender_output_loss: 0.4097 - loss: 23.4566 - val_age_output_loss: 13.5287 - val_age_output_mae: 7.7454 - val_ethnicity_output_accuracy: 0.7049 - val_ethnicity_output_loss: 0.7957 - val_gender_output_accuracy: 0.8448 - val_gender_output_loss: 0.3490 - val_loss: 23.3531 - learning_rate: 2.0000e-04
# Epoch 19/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 13.3061 - age_output_mae: 7.5845 - ethnicity_output_accuracy: 0.6557 - ethnicity_output_loss: 0.9334 - gender_output_accuracy: 0.8175 - gender_output_loss: 0.3968 - loss: 23.1698 - val_age_output_loss: 16.2006 - val_age_output_mae: 9.0399 - val_ethnicity_output_accuracy: 0.6752 - val_ethnicity_output_loss: 0.8296 - val_gender_output_accuracy: 0.8327 - val_gender_output_loss: 0.3500 - val_loss: 27.2952 - learning_rate: 2.0000e-04
# Epoch 20/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 13.1366 - age_output_mae: 7.4992 - ethnicity_output_accuracy: 0.6652 - ethnicity_output_loss: 0.9196 - gender_output_accuracy: 0.8146 - gender_output_loss: 0.3937 - loss: 22.8838 - val_age_output_loss: 16.3166 - val_age_output_mae: 9.0621 - val_ethnicity_output_accuracy: 0.6885 - val_ethnicity_output_loss: 0.8076 - val_gender_output_accuracy: 0.8348 - val_gender_output_loss: 0.3497 - val_loss: 27.2909 - learning_rate: 2.0000e-04
# Epoch 21/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 13.0593 - age_output_mae: 7.4586 - ethnicity_output_accuracy: 0.6622 - ethnicity_output_loss: 0.9247 - gender_output_accuracy: 0.8204 - gender_output_loss: 0.3904 - loss: 22.7743 - val_age_output_loss: 16.4222 - val_age_output_mae: 9.1028 - val_ethnicity_output_accuracy: 0.7049 - val_ethnicity_output_loss: 0.7900 - val_gender_output_accuracy: 0.8433 - val_gender_output_loss: 0.3441 - val_loss: 27.3655 - learning_rate: 2.0000e-04
# Epoch 22/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - age_output_loss: 12.6149 - age_output_mae: 7.2337 - ethnicity_output_accuracy: 0.6630 - ethnicity_output_loss: 0.9141 - gender_output_accuracy: 0.8174 - gender_output_loss: 0.3841 - loss: 22.0789 - val_age_output_loss: 14.6513 - val_age_output_mae: 8.2271 - val_ethnicity_output_accuracy: 0.6851 - val_ethnicity_output_loss: 0.8145 - val_gender_output_accuracy: 0.8342 - val_gender_output_loss: 0.3501 - val_loss: 24.8165 - learning_rate: 2.0000e-04
# Epoch 23/100
# 145/149 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - age_output_loss: 12.8082 - age_output_mae: 7.3311 - ethnicity_output_accuracy: 0.6770 - ethnicity_output_loss: 0.8830 - gender_output_accuracy: 0.8291 - gender_output_loss: 0.3771 - loss: 22.2995
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 12.8042 - age_output_mae: 7.3290 - ethnicity_output_accuracy: 0.6770 - ethnicity_output_loss: 0.8831 - gender_output_accuracy: 0.8290 - gender_output_loss: 0.3772 - loss: 22.2936 - val_age_output_loss: 16.3673 - val_age_output_mae: 9.0990 - val_ethnicity_output_accuracy: 0.7070 - val_ethnicity_output_loss: 0.7746 - val_gender_output_accuracy: 0.8488 - val_gender_output_loss: 0.3357 - val_loss: 27.3176 - learning_rate: 2.0000e-04
# Epoch 24/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 12.5308 - age_output_mae: 7.1923 - ethnicity_output_accuracy: 0.6824 - ethnicity_output_loss: 0.8680 - gender_output_accuracy: 0.8231 - gender_output_loss: 0.3770 - loss: 21.8527 - val_age_output_loss: 13.9265 - val_age_output_mae: 7.8699 - val_ethnicity_output_accuracy: 0.7218 - val_ethnicity_output_loss: 0.7469 - val_gender_output_accuracy: 0.8473 - val_gender_output_loss: 0.3403 - val_loss: 23.6175 - learning_rate: 1.0000e-04
# Epoch 25/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 12.4374 - age_output_mae: 7.1501 - ethnicity_output_accuracy: 0.6940 - ethnicity_output_loss: 0.8520 - gender_output_accuracy: 0.8230 - gender_output_loss: 0.3810 - loss: 21.6840 - val_age_output_loss: 17.1475 - val_age_output_mae: 9.4488 - val_ethnicity_output_accuracy: 0.6889 - val_ethnicity_output_loss: 0.8126 - val_gender_output_accuracy: 0.8486 - val_gender_output_loss: 0.3349 - val_loss: 28.4349 - learning_rate: 1.0000e-04
# Epoch 26/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 12.7038 - age_output_mae: 7.2800 - ethnicity_output_accuracy: 0.6874 - ethnicity_output_loss: 0.8574 - gender_output_accuracy: 0.8239 - gender_output_loss: 0.3781 - loss: 22.0893 - val_age_output_loss: 15.9904 - val_age_output_mae: 8.8696 - val_ethnicity_output_accuracy: 0.6992 - val_ethnicity_output_loss: 0.7932 - val_gender_output_accuracy: 0.8437 - val_gender_output_loss: 0.3325 - val_loss: 26.6610 - learning_rate: 1.0000e-04
# Epoch 27/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 12.5519 - age_output_mae: 7.2018 - ethnicity_output_accuracy: 0.6862 - ethnicity_output_loss: 0.8687 - gender_output_accuracy: 0.8275 - gender_output_loss: 0.3675 - loss: 21.8723 - val_age_output_loss: 17.1674 - val_age_output_mae: 9.4284 - val_ethnicity_output_accuracy: 0.7176 - val_ethnicity_output_loss: 0.7554 - val_gender_output_accuracy: 0.8467 - val_gender_output_loss: 0.3332 - val_loss: 28.2588 - learning_rate: 1.0000e-04
# Epoch 28/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 12.3276 - age_output_mae: 7.0924 - ethnicity_output_accuracy: 0.6903 - ethnicity_output_loss: 0.8610 - gender_output_accuracy: 0.8251 - gender_output_loss: 0.3776 - loss: 21.5308 - val_age_output_loss: 13.7559 - val_age_output_mae: 7.7634 - val_ethnicity_output_accuracy: 0.7283 - val_ethnicity_output_loss: 0.7306 - val_gender_output_accuracy: 0.8445 - val_gender_output_loss: 0.3345 - val_loss: 23.2466 - learning_rate: 1.0000e-04
# Epoch 29/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 12.1876 - age_output_mae: 7.0165 - ethnicity_output_accuracy: 0.6920 - ethnicity_output_loss: 0.8614 - gender_output_accuracy: 0.8288 - gender_output_loss: 0.3623 - loss: 21.3053 - val_age_output_loss: 13.1865 - val_age_output_mae: 7.4911 - val_ethnicity_output_accuracy: 0.7216 - val_ethnicity_output_loss: 0.7439 - val_gender_output_accuracy: 0.8395 - val_gender_output_loss: 0.3350 - val_loss: 22.4579 - learning_rate: 1.0000e-04
# Epoch 30/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 12.2987 - age_output_mae: 7.0770 - ethnicity_output_accuracy: 0.6857 - ethnicity_output_loss: 0.8596 - gender_output_accuracy: 0.8293 - gender_output_loss: 0.3682 - loss: 21.4735 - val_age_output_loss: 16.6877 - val_age_output_mae: 9.2068 - val_ethnicity_output_accuracy: 0.7127 - val_ethnicity_output_loss: 0.7681 - val_gender_output_accuracy: 0.8386 - val_gender_output_loss: 0.3475 - val_loss: 27.6227 - learning_rate: 1.0000e-04
# Epoch 31/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 12.0456 - age_output_mae: 6.9476 - ethnicity_output_accuracy: 0.6910 - ethnicity_output_loss: 0.8470 - gender_output_accuracy: 0.8313 - gender_output_loss: 0.3713 - loss: 21.0708 - val_age_output_loss: 16.5370 - val_age_output_mae: 9.1280 - val_ethnicity_output_accuracy: 0.7013 - val_ethnicity_output_loss: 0.7948 - val_gender_output_accuracy: 0.8325 - val_gender_output_loss: 0.3451 - val_loss: 27.4463 - learning_rate: 1.0000e-04
# Epoch 32/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 12.1196 - age_output_mae: 6.9829 - ethnicity_output_accuracy: 0.6956 - ethnicity_output_loss: 0.8515 - gender_output_accuracy: 0.8294 - gender_output_loss: 0.3687 - loss: 21.1875 - val_age_output_loss: 13.0552 - val_age_output_mae: 7.4251 - val_ethnicity_output_accuracy: 0.7349 - val_ethnicity_output_loss: 0.7196 - val_gender_output_accuracy: 0.8486 - val_gender_output_loss: 0.3243 - val_loss: 22.2094 - learning_rate: 1.0000e-04
# Epoch 33/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.9706 - age_output_mae: 6.9099 - ethnicity_output_accuracy: 0.6845 - ethnicity_output_loss: 0.8508 - gender_output_accuracy: 0.8348 - gender_output_loss: 0.3597 - loss: 20.9523 - val_age_output_loss: 13.4437 - val_age_output_mae: 7.6024 - val_ethnicity_output_accuracy: 0.7235 - val_ethnicity_output_loss: 0.7420 - val_gender_output_accuracy: 0.8494 - val_gender_output_loss: 0.3221 - val_loss: 22.7759 - learning_rate: 1.0000e-04
# Epoch 34/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 12.0146 - age_output_mae: 6.9332 - ethnicity_output_accuracy: 0.6909 - ethnicity_output_loss: 0.8465 - gender_output_accuracy: 0.8371 - gender_output_loss: 0.3594 - loss: 21.0091 - val_age_output_loss: 13.6023 - val_age_output_mae: 7.6873 - val_ethnicity_output_accuracy: 0.7252 - val_ethnicity_output_loss: 0.7327 - val_gender_output_accuracy: 0.8580 - val_gender_output_loss: 0.3119 - val_loss: 22.9925 - learning_rate: 1.0000e-04
# Epoch 35/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 12.0860 - age_output_mae: 6.9683 - ethnicity_output_accuracy: 0.6997 - ethnicity_output_loss: 0.8381 - gender_output_accuracy: 0.8345 - gender_output_loss: 0.3609 - loss: 21.0998 - val_age_output_loss: 13.4125 - val_age_output_mae: 7.6027 - val_ethnicity_output_accuracy: 0.7226 - val_ethnicity_output_loss: 0.7451 - val_gender_output_accuracy: 0.8583 - val_gender_output_loss: 0.3122 - val_loss: 22.7772 - learning_rate: 1.0000e-04
# Epoch 36/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.9411 - age_output_mae: 6.8957 - ethnicity_output_accuracy: 0.7003 - ethnicity_output_loss: 0.8348 - gender_output_accuracy: 0.8386 - gender_output_loss: 0.3500 - loss: 20.8644 - val_age_output_loss: 13.9717 - val_age_output_mae: 7.8440 - val_ethnicity_output_accuracy: 0.7281 - val_ethnicity_output_loss: 0.7391 - val_gender_output_accuracy: 0.8578 - val_gender_output_loss: 0.3101 - val_loss: 23.4625 - learning_rate: 1.0000e-04
# Epoch 37/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - age_output_loss: 12.1439 - age_output_mae: 6.9981 - ethnicity_output_accuracy: 0.7020 - ethnicity_output_loss: 0.8171 - gender_output_accuracy: 0.8393 - gender_output_loss: 0.3520 - loss: 21.1342 - val_age_output_loss: 12.4549 - val_age_output_mae: 7.1227 - val_ethnicity_output_accuracy: 0.7353 - val_ethnicity_output_loss: 0.7136 - val_gender_output_accuracy: 0.8500 - val_gender_output_loss: 0.3210 - val_loss: 21.2894 - learning_rate: 1.0000e-04
# Epoch 38/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - age_output_loss: 12.0961 - age_output_mae: 6.9710 - ethnicity_output_accuracy: 0.6983 - ethnicity_output_loss: 0.8319 - gender_output_accuracy: 0.8353 - gender_output_loss: 0.3544 - loss: 21.0935 - val_age_output_loss: 13.1910 - val_age_output_mae: 7.4860 - val_ethnicity_output_accuracy: 0.7374 - val_ethnicity_output_loss: 0.7069 - val_gender_output_accuracy: 0.8621 - val_gender_output_loss: 0.3026 - val_loss: 22.3303 - learning_rate: 1.0000e-04
# Epoch 39/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.7228 - age_output_mae: 6.7834 - ethnicity_output_accuracy: 0.6988 - ethnicity_output_loss: 0.8252 - gender_output_accuracy: 0.8418 - gender_output_loss: 0.3505 - loss: 20.5155 - val_age_output_loss: 12.5442 - val_age_output_mae: 7.1656 - val_ethnicity_output_accuracy: 0.7359 - val_ethnicity_output_loss: 0.7154 - val_gender_output_accuracy: 0.8640 - val_gender_output_loss: 0.3031 - val_loss: 21.4040 - learning_rate: 1.0000e-04
# Epoch 40/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.8187 - age_output_mae: 6.8312 - ethnicity_output_accuracy: 0.7065 - ethnicity_output_loss: 0.8144 - gender_output_accuracy: 0.8370 - gender_output_loss: 0.3568 - loss: 20.6434 - val_age_output_loss: 12.6969 - val_age_output_mae: 7.2253 - val_ethnicity_output_accuracy: 0.7344 - val_ethnicity_output_loss: 0.7208 - val_gender_output_accuracy: 0.8549 - val_gender_output_loss: 0.3103 - val_loss: 21.6000 - learning_rate: 1.0000e-04
# Epoch 41/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.7422 - age_output_mae: 6.7927 - ethnicity_output_accuracy: 0.7019 - ethnicity_output_loss: 0.8304 - gender_output_accuracy: 0.8425 - gender_output_loss: 0.3531 - loss: 20.5559 - val_age_output_loss: 13.9216 - val_age_output_mae: 7.8275 - val_ethnicity_output_accuracy: 0.7129 - val_ethnicity_output_loss: 0.7650 - val_gender_output_accuracy: 0.8572 - val_gender_output_loss: 0.3083 - val_loss: 23.4734 - learning_rate: 1.0000e-04
# Epoch 42/100
# 144/149 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - age_output_loss: 11.8417 - age_output_mae: 6.8454 - ethnicity_output_accuracy: 0.7024 - ethnicity_output_loss: 0.8229 - gender_output_accuracy: 0.8417 - gender_output_loss: 0.3426 - loss: 20.6788
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.8384 - age_output_mae: 6.8438 - ethnicity_output_accuracy: 0.7026 - ethnicity_output_loss: 0.8226 - gender_output_accuracy: 0.8417 - gender_output_loss: 0.3426 - loss: 20.6733 - val_age_output_loss: 12.7764 - val_age_output_mae: 7.2685 - val_ethnicity_output_accuracy: 0.7235 - val_ethnicity_output_loss: 0.7415 - val_gender_output_accuracy: 0.8549 - val_gender_output_loss: 0.3112 - val_loss: 21.7744 - learning_rate: 1.0000e-04
# Epoch 43/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.6343 - age_output_mae: 6.7412 - ethnicity_output_accuracy: 0.7054 - ethnicity_output_loss: 0.8229 - gender_output_accuracy: 0.8438 - gender_output_loss: 0.3379 - loss: 20.3618 - val_age_output_loss: 13.8937 - val_age_output_mae: 7.7945 - val_ethnicity_output_accuracy: 0.7298 - val_ethnicity_output_loss: 0.7215 - val_gender_output_accuracy: 0.8604 - val_gender_output_loss: 0.3052 - val_loss: 23.2885 - learning_rate: 5.0000e-05
# Epoch 44/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - age_output_loss: 11.6990 - age_output_mae: 6.7717 - ethnicity_output_accuracy: 0.7023 - ethnicity_output_loss: 0.8238 - gender_output_accuracy: 0.8485 - gender_output_loss: 0.3393 - loss: 20.4624 - val_age_output_loss: 12.8298 - val_age_output_mae: 7.2892 - val_ethnicity_output_accuracy: 0.7330 - val_ethnicity_output_loss: 0.7169 - val_gender_output_accuracy: 0.8665 - val_gender_output_loss: 0.2977 - val_loss: 21.7634 - learning_rate: 5.0000e-05
# Epoch 45/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - age_output_loss: 11.6118 - age_output_mae: 6.7267 - ethnicity_output_accuracy: 0.7047 - ethnicity_output_loss: 0.8241 - gender_output_accuracy: 0.8461 - gender_output_loss: 0.3366 - loss: 20.3283 - val_age_output_loss: 13.4222 - val_age_output_mae: 7.5779 - val_ethnicity_output_accuracy: 0.7294 - val_ethnicity_output_loss: 0.7276 - val_gender_output_accuracy: 0.8629 - val_gender_output_loss: 0.3031 - val_loss: 22.6566 - learning_rate: 5.0000e-05
# Epoch 46/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.2536 - age_output_mae: 6.5466 - ethnicity_output_accuracy: 0.7065 - ethnicity_output_loss: 0.8137 - gender_output_accuracy: 0.8442 - gender_output_loss: 0.3381 - loss: 19.7714 - val_age_output_loss: 12.0310 - val_age_output_mae: 6.9124 - val_ethnicity_output_accuracy: 0.7353 - val_ethnicity_output_loss: 0.7084 - val_gender_output_accuracy: 0.8621 - val_gender_output_loss: 0.3003 - val_loss: 20.6326 - learning_rate: 5.0000e-05
# Epoch 47/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.5289 - age_output_mae: 6.6838 - ethnicity_output_accuracy: 0.7064 - ethnicity_output_loss: 0.8111 - gender_output_accuracy: 0.8460 - gender_output_loss: 0.3426 - loss: 20.1826 - val_age_output_loss: 13.5347 - val_age_output_mae: 7.6284 - val_ethnicity_output_accuracy: 0.7298 - val_ethnicity_output_loss: 0.7234 - val_gender_output_accuracy: 0.8661 - val_gender_output_loss: 0.2984 - val_loss: 22.7822 - learning_rate: 5.0000e-05
# Epoch 48/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.4877 - age_output_mae: 6.6671 - ethnicity_output_accuracy: 0.7146 - ethnicity_output_loss: 0.7949 - gender_output_accuracy: 0.8457 - gender_output_loss: 0.3390 - loss: 20.0846 - val_age_output_loss: 12.1060 - val_age_output_mae: 6.9292 - val_ethnicity_output_accuracy: 0.7387 - val_ethnicity_output_loss: 0.7017 - val_gender_output_accuracy: 0.8631 - val_gender_output_loss: 0.3018 - val_loss: 20.6736 - learning_rate: 5.0000e-05
# Epoch 49/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.3544 - age_output_mae: 6.5989 - ethnicity_output_accuracy: 0.7102 - ethnicity_output_loss: 0.8026 - gender_output_accuracy: 0.8467 - gender_output_loss: 0.3358 - loss: 19.8965 - val_age_output_loss: 12.3906 - val_age_output_mae: 7.0807 - val_ethnicity_output_accuracy: 0.7385 - val_ethnicity_output_loss: 0.7008 - val_gender_output_accuracy: 0.8675 - val_gender_output_loss: 0.2957 - val_loss: 21.1096 - learning_rate: 5.0000e-05
# Epoch 50/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.4381 - age_output_mae: 6.6400 - ethnicity_output_accuracy: 0.7141 - ethnicity_output_loss: 0.8055 - gender_output_accuracy: 0.8491 - gender_output_loss: 0.3343 - loss: 20.0257 - val_age_output_loss: 12.1520 - val_age_output_mae: 6.9732 - val_ethnicity_output_accuracy: 0.7416 - val_ethnicity_output_loss: 0.6951 - val_gender_output_accuracy: 0.8667 - val_gender_output_loss: 0.2988 - val_loss: 20.7805 - learning_rate: 5.0000e-05
# Epoch 51/100
# 145/149 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - age_output_loss: 11.3853 - age_output_mae: 6.6142 - ethnicity_output_accuracy: 0.7152 - ethnicity_output_loss: 0.7917 - gender_output_accuracy: 0.8440 - gender_output_loss: 0.3450 - loss: 19.9289
# Epoch 51: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.3866 - age_output_mae: 6.6148 - ethnicity_output_accuracy: 0.7151 - ethnicity_output_loss: 0.7918 - gender_output_accuracy: 0.8441 - gender_output_loss: 0.3448 - loss: 19.9309 - val_age_output_loss: 14.1372 - val_age_output_mae: 7.9331 - val_ethnicity_output_accuracy: 0.7235 - val_ethnicity_output_loss: 0.7374 - val_gender_output_accuracy: 0.8640 - val_gender_output_loss: 0.2945 - val_loss: 23.6961 - learning_rate: 5.0000e-05
# Epoch 52/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - age_output_loss: 11.3206 - age_output_mae: 6.5824 - ethnicity_output_accuracy: 0.7093 - ethnicity_output_loss: 0.8111 - gender_output_accuracy: 0.8494 - gender_output_loss: 0.3340 - loss: 19.8589 - val_age_output_loss: 12.8858 - val_age_output_mae: 7.3143 - val_ethnicity_output_accuracy: 0.7366 - val_ethnicity_output_loss: 0.7052 - val_gender_output_accuracy: 0.8656 - val_gender_output_loss: 0.2944 - val_loss: 21.8070 - learning_rate: 2.5000e-05
# Epoch 53/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.3352 - age_output_mae: 6.5850 - ethnicity_output_accuracy: 0.7182 - ethnicity_output_loss: 0.7876 - gender_output_accuracy: 0.8463 - gender_output_loss: 0.3383 - loss: 19.8381 - val_age_output_loss: 12.5075 - val_age_output_mae: 7.1279 - val_ethnicity_output_accuracy: 0.7408 - val_ethnicity_output_loss: 0.7006 - val_gender_output_accuracy: 0.8686 - val_gender_output_loss: 0.2920 - val_loss: 21.2519 - learning_rate: 2.5000e-05
# Epoch 54/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.2646 - age_output_mae: 6.5533 - ethnicity_output_accuracy: 0.7138 - ethnicity_output_loss: 0.8002 - gender_output_accuracy: 0.8473 - gender_output_loss: 0.3347 - loss: 19.7533 - val_age_output_loss: 13.1069 - val_age_output_mae: 7.4137 - val_ethnicity_output_accuracy: 0.7418 - val_ethnicity_output_loss: 0.6974 - val_gender_output_accuracy: 0.8680 - val_gender_output_loss: 0.2944 - val_loss: 22.0933 - learning_rate: 2.5000e-05
# Epoch 55/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.5392 - age_output_mae: 6.6930 - ethnicity_output_accuracy: 0.7124 - ethnicity_output_loss: 0.8065 - gender_output_accuracy: 0.8534 - gender_output_loss: 0.3341 - loss: 20.1773 - val_age_output_loss: 14.4930 - val_age_output_mae: 8.0959 - val_ethnicity_output_accuracy: 0.7340 - val_ethnicity_output_loss: 0.7146 - val_gender_output_accuracy: 0.8673 - val_gender_output_loss: 0.2950 - val_loss: 24.1376 - learning_rate: 2.5000e-05
# Epoch 56/100
# 145/149 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - age_output_loss: 11.3393 - age_output_mae: 6.5915 - ethnicity_output_accuracy: 0.7150 - ethnicity_output_loss: 0.8006 - gender_output_accuracy: 0.8475 - gender_output_loss: 0.3392 - loss: 19.8702
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - age_output_loss: 11.3377 - age_output_mae: 6.5907 - ethnicity_output_accuracy: 0.7151 - ethnicity_output_loss: 0.8004 - gender_output_accuracy: 0.8475 - gender_output_loss: 0.3392 - loss: 19.8677 - val_age_output_loss: 12.5460 - val_age_output_mae: 7.1379 - val_ethnicity_output_accuracy: 0.7408 - val_ethnicity_output_loss: 0.6991 - val_gender_output_accuracy: 0.8663 - val_gender_output_loss: 0.2938 - val_loss: 21.2806 - learning_rate: 2.5000e-05
# Epoch 56: early stopping
# Restoring model weights from the end of the best epoch: 46.

# %%
#Evaluation
evaluation = multi_feature_model.evaluate(X_test, {
    'age_output': y_age_test,
    'gender_output': y_gender_test,
    'ethnicity_output': y_eth_test
})
print('Test Results:', evaluation)
# Out:
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - age_output_loss: 11.9430 - age_output_mae: 6.8995 - ethnicity_output_accuracy: 0.7317 - ethnicity_output_loss: 0.7333 - gender_output_accuracy: 0.8679 - gender_output_loss: 0.2885 - loss: 20.5943
# Test Results: [20.63271713256836, 11.988649368286133, 0.2986992299556732, 0.719329297542572, 6.9124436378479, 0.7352879047393799, 0.8622653484344482]

# %%
#Evaluation Table
metric_names = [
    'Total Loss (weighted)',
    'Age Loss (Huber)',
    'Gender Loss (Crossentropy)',
    'Ethnicity Loss (Crossentropy)',
    'Age MAE (years)',
    'Ethnicity Accuracy',
    'Gender Accuracy'
]

print("\n📊 Model Evaluation Results:")
print("-" * 50)
for name, value in zip(metric_names, evaluation):
    if "Accuracy" in name:
        print(f"{name:<35}: {value:.2%}")
    elif "MAE" in name:
        print(f"{name:<35}: {value:.4f}")

    else:
        print(f"{name:<35}: {value:.4f}")
print("-" * 50)
# Out:
# 📊 Model Evaluation Results:
# --------------------------------------------------
# Total Loss (weighted)              : 20.6327
# Age Loss (Huber)                   : 11.9886
# Gender Loss (Crossentropy)         : 0.2987
# Ethnicity Loss (Crossentropy)      : 0.7193
# Age MAE (years)                    : 6.9124
# Ethnicity Accuracy                 : 73.53%
# Gender Accuracy                    : 86.23%
# --------------------------------------------------

# %%
# !pip install streamlit opencv-python-headless pyngrok tensorflow
# Out:
# Collecting streamlit
#   Downloading streamlit-1.45.0-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting pyngrok
#   Downloading pyngrok-7.2.5-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.4)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.13.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.36.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.24.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading streamlit-1.45.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 101.5 MB/s eta 0:00:00
# Downloading pyngrok-7.2.5-py3-none-any.whl (23 kB)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 114.9 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.9 MB/s eta 0:00:00
# Installing collected packages: watchdog, pyngrok, pydeck, streamlit
# Successfully installed pydeck-0.9.1 pyngrok-7.2.5 streamlit-1.45.0 watchdog-6.0.0

# %%
multi_feature_model.save("multi_feature_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from google.colab import files
files.download('multi_feature_model.h5')
