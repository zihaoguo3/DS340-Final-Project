# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import os
os.environ["OMP_NUM_THREADS"] = "8"
os.environ["TF_NUM_INTRAOP_THREADS"] = "8" 
os.environ["TF_NUM_INTEROP_THREADS"] = "2"
import tensorflow as tf
tf.config.threading.set_intra_op_parallelism_threads(8)
tf.config.threading.set_inter_op_parallelism_threads(2)
from tensorflow.keras.layers import Dense, Activation, Input, Conv2D, MaxPooling2D, Add, BatchNormalization, Dropout, Flatten,GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import ast

from tensorflow.keras.utils import to_categorical

# %%
df = pd.read_csv("combined_dataset.csv")
print(df.head())
df.info()
df.isnull().sum()
# Out:
#    age  ethnicity  gender                                             pixels
# 0   28          4       1  [164, 164, 164, 164, 163, 163, 163, 163, 164, ...
# 1    1          0       0  [223, 224, 224, 224, 224, 224, 224, 226, 224, ...
# 2    4          4       1  [182, 184, 185, 186, 188, 191, 194, 195, 197, ...
# 3   85          0       0  [25, 29, 126, 145, 36, 39, 46, 53, 57, 23, 38,...
# 4   75          1       0  [13, 14, 17, 18, 18, 19, 19, 19, 17, 62, 117, ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33840 entries, 0 to 33839
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        33840 non-null  int64
#  1   ethnicity  33840 non-null  int64
#  2   gender     33840 non-null  int64
#  3   pixels     33840 non-null  object
# dtypes: int64(3), object(1)
# memory usage: 1.0+ MB
# age          0
# ethnicity    0
# gender       0
# pixels       0
# dtype: int64

# %%
# Load your combined dataset
df = pd.read_csv("combined_dataset.csv")

# Convert stringified lists into actual Python lists
df['pixels'] = df['pixels'].apply(ast.literal_eval)

# Now convert to numpy arrays
X = np.stack(df['pixels'].values).astype(np.uint8)
X = X.reshape(-1, 48, 48, 1)  # Add channel dimension for CNN

# Extract labels
y = df.drop(columns=["pixels"])

print("✅ X shape:", X.shape)
print("✅ y shape:", y.shape)
# Out:
# ✅ X shape: (33840, 48, 48, 1)
# ✅ y shape: (33840, 3)

# %%
ethnicity_indices = []

for race in range(5):
    index = y[y['ethnicity'] == race].index[0]  # first match
    ethnicity_indices.append(index)

fig, axes = plt.subplots(1, 5, figsize=(15, 3))
for i, ax in enumerate(axes):
    idx = ethnicity_indices[i]
    ax.imshow(X[idx].squeeze(), cmap='gray')
    ax.axis("off")
    ax.set_title(
        f"Age: {y['age'].iloc[idx]}\nEthnicity: {y['ethnicity'].iloc[idx]}\nGender: {y['gender'].iloc[idx]}",
        fontsize=10
    )

plt.tight_layout()
plt.show()

# %%
X = X / 255.0
ethnicity_matrix = np.array(y["ethnicity"])
num_classes = 5  # update if needed based on your dataset
ethnicity = to_categorical(ethnicity_matrix, num_classes=num_classes)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, ethnicity, test_size=0.2, random_state=42, stratify=ethnicity_matrix
)

# %%
def ConvFunc(x, filters = 16, kernel_size = (3, 3),dropout_rate=0.1):
    x = Conv2D(filters, kernel_size = kernel_size, padding = "same",
              kernel_initializer="he_normal", kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization(momentum=0.95)(x)
    x = Activation("relu")(x)
    x = MaxPooling2D()(x)

    return x


def create_ethnicity_model():
    inputs = Input(shape = (48, 48, 1))

    x = ConvFunc(inputs, 32, dropout_rate=0.1)
    x = ConvFunc(x, 64, dropout_rate=0.15)
    x = ConvFunc(x, 128, dropout_rate=0.2)
    x = ConvFunc(x, 256, dropout_rate=0.25)

    x = Flatten()(x)
    x = Dense(256, activation="relu", kernel_regularizer=l2(0.001))(x)
    x = Dropout(0.4)(x)
    

    outputs = Dense(num_classes, activation="softmax")(x)

    
    model = Model(inputs, outputs)

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0003, epsilon=1e-7)

    model.compile(
        optimizer=optimizer,
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model
ethnicity_model = create_ethnicity_model()
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True, verbose=1
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_accuracy", patience=5, verbose=1, factor=0.5, min_lr=1e-5
)

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)
datagen.fit(X_train)

ethnicity_model.fit(
    datagen.flow(X_train, y_train, batch_size=64),
    validation_data=(X_test, y_test),
    epochs=50,
    callbacks=[early_stopping, lr_scheduler],
    verbose=1
)
# Out:
# Epoch 1/50
# 423/423 [==============================] - 10s 22ms/step - loss: 2.6513 - accuracy: 0.4838 - val_loss: 2.3965 - val_accuracy: 0.5465 - lr: 3.0000e-04
# Epoch 2/50
# 423/423 [==============================] - 9s 22ms/step - loss: 2.2660 - accuracy: 0.5464 - val_loss: 2.0383 - val_accuracy: 0.6067 - lr: 3.0000e-04
# Epoch 3/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.9812 - accuracy: 0.5887 - val_loss: 1.8337 - val_accuracy: 0.6217 - lr: 3.0000e-04
# Epoch 4/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.7635 - accuracy: 0.6186 - val_loss: 1.6279 - val_accuracy: 0.6399 - lr: 3.0000e-04
# Epoch 5/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.6029 - accuracy: 0.6352 - val_loss: 1.5229 - val_accuracy: 0.6469 - lr: 3.0000e-04
# Epoch 6/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.4847 - accuracy: 0.6430 - val_loss: 1.4010 - val_accuracy: 0.6729 - lr: 3.0000e-04
# Epoch 7/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.3862 - accuracy: 0.6532 - val_loss: 1.3405 - val_accuracy: 0.6622 - lr: 3.0000e-04
# Epoch 8/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.3094 - accuracy: 0.6615 - val_loss: 1.2249 - val_accuracy: 0.6865 - lr: 3.0000e-04
# Epoch 9/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.2464 - accuracy: 0.6719 - val_loss: 1.2434 - val_accuracy: 0.6689 - lr: 3.0000e-04
# Epoch 10/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.2101 - accuracy: 0.6759 - val_loss: 1.1333 - val_accuracy: 0.6943 - lr: 3.0000e-04
# Epoch 11/50
# 423/423 [==============================] - 9s 21ms/step - loss: 1.1588 - accuracy: 0.6830 - val_loss: 1.2366 - val_accuracy: 0.6684 - lr: 3.0000e-04
# Epoch 12/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.1264 - accuracy: 0.6863 - val_loss: 1.1284 - val_accuracy: 0.6865 - lr: 3.0000e-04
# Epoch 13/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.1106 - accuracy: 0.6880 - val_loss: 1.0749 - val_accuracy: 0.6913 - lr: 3.0000e-04
# Epoch 14/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.0806 - accuracy: 0.6933 - val_loss: 1.1085 - val_accuracy: 0.6736 - lr: 3.0000e-04
# Epoch 15/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.0637 - accuracy: 0.7001 - val_loss: 1.0535 - val_accuracy: 0.7079 - lr: 3.0000e-04
# Epoch 16/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.0447 - accuracy: 0.7043 - val_loss: 1.1643 - val_accuracy: 0.6806 - lr: 3.0000e-04
# Epoch 17/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.0294 - accuracy: 0.7034 - val_loss: 1.1372 - val_accuracy: 0.6659 - lr: 3.0000e-04
# Epoch 18/50
# 423/423 [==============================] - 9s 22ms/step - loss: 1.0149 - accuracy: 0.7071 - val_loss: 1.0991 - val_accuracy: 0.6673 - lr: 3.0000e-04
# Epoch 19/50
# 423/423 [==============================] - 9s 22ms/step - loss: 0.9994 - accuracy: 0.7112 - val_loss: 1.0644 - val_accuracy: 0.6848 - lr: 3.0000e-04
# Epoch 20/50
# 421/423 [============================>.] - ETA: 0s - loss: 0.9917 - accuracy: 0.7138
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 423/423 [==============================] - 9s 22ms/step - loss: 0.
50
# 423/423 [==============================] - 9s 22ms/step - loss: 0.7728 - accuracy: 0.7781 - val_loss: 0.8833 - val_accuracy: 0.7478 - lr: 3.7500e-05
# Epoch 45/50
# 423/423 [==============================] - 9s 22ms/step - loss: 0.7675 - accuracy: 0.7791 - val_loss: 0.8885 - val_accuracy: 0.7485 - lr: 3.7500e-05
# Epoch 46/50
# 423/423 [==============================] - 9s 22ms/step - loss: 0.7679 - accuracy: 0.7803 - val_loss: 0.8972 - val_accuracy: 0.7504 - lr: 3.7500e-05
# Epoch 47/50
# 423/423 [==============================] - 9s 22ms/step - loss: 0.7567 - accuracy: 0.7850 - val_loss: 0.8965 - val_accuracy: 0.7497 - lr: 3.7500e-05
# Epoch 48/50
# 423/423 [==============================] - 9s 22ms/step - loss: 0.7563 - accuracy: 0.7833 - val_loss: 0.9431 - val_accuracy: 0.7450 - lr: 3.7500e-05
# Epoch 49/50
# 423/423 [==============================] - 9s 22ms/step - loss: 0.7600 - accuracy: 0.7825 - val_loss: 0.8942 - val_accuracy: 0.7496 - lr: 3.7500e-05
# Epoch 50/50
# 423/423 [==============================] - 9s 22ms/step - loss: 0.7560 - accuracy: 0.7856 - val_loss: 0.8763 - val_accuracy: 0.7527 - lr: 3.7500e-05

# %%
ethnicity_model.save_weights("ethnicity_weights_2.h5")

# %%
ethnicity_model.evaluate(X_test, y_test)
# Out:
# 212/212 [==============================] - 1s 4ms/step - loss: 0.8763 - accuracy: 0.7527
# [0.8763214349746704, 0.7526595592498779]

# %%
print(df['age'].max())
age=df['age']
# Out:
# 116

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, age, test_size=0.2, random_state=42
)

# %%
y_train = np.array(y_train).astype("float32")  
y_test = np.array(y_test).astype("float32")
y_train = y_train / 116
y_test = y_test / 116

# %%
print("Max y_train:", y_train.max())  
print("Min y_train:", y_train.min())
# Out:
# Max y_train: 1.0
# Min y_train: 0.00862069

# %%
def ConvBlock(x, filters, dropout_rate=0.1):
    x = Conv2D(filters, kernel_size=(3, 3), padding="same",
               kernel_initializer="he_normal", kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(filters, kernel_size=(3, 3), padding="same",
               kernel_initializer="he_normal", kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(dropout_rate)(x)
    return x

def create_deep_age_model():
    inputs = Input(shape=(48, 48, 1))

    x = ConvBlock(inputs, 32, dropout_rate=0.1)
    x = ConvBlock(x, 64, dropout_rate=0.15)
    x = ConvBlock(x, 128, dropout_rate=0.2)
    x = ConvBlock(x, 256, dropout_rate=0.25)
    x = ConvBlock(x, 512, dropout_rate=0.3)  # 5th block for extra depth

    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation="relu", kernel_regularizer=l2(0.001))(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation="relu", kernel_regularizer=l2(0.001))(x)
    x = Dropout(0.4)(x)

    outputs = Dense(1, activation="softplus")(x)  # Predicts positive age

    model = Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=2e-4),
        loss=tf.keras.losses.Huber(delta=2.0),  # robust to outliers
        metrics=["mae"]
    )
    return model

age_model = create_deep_age_model()
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=12, restore_best_weights=True, verbose=1
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss", patience=6, factor=0.5, verbose=1, min_lr=1e-5
)

# %%
age_model.fit(
    X_train, y_train,
    batch_size=128,
    validation_data=(X_test, y_test),
    epochs=50,
    callbacks=[early_stopping, lr_scheduler],
    verbose=1
)
# Out:
# Epoch 1/50
# 212/212 [==============================] - 47s 204ms/step - loss: 3.9739 - mae: 0.2398 - val_loss: 3.2788 - val_mae: 0.1832 - lr: 2.0000e-04
# Epoch 2/50
# 212/212 [==============================] - 42s 200ms/step - loss: 2.6884 - mae: 0.1593 - val_loss: 2.1652 - val_mae: 0.2182 - lr: 2.0000e-04
# Epoch 3/50
# 212/212 [==============================] - 43s 204ms/step - loss: 1.7457 - mae: 0.1415 - val_loss: 1.4219 - val_mae: 0.2771 - lr: 2.0000e-04
# Epoch 45/50
# 212/212 [==============================] - 41s 193ms/step - loss: 0.0085 - mae: 0.0674 - val_loss: 0.0132 - val_mae: 0.0956 - lr: 1.0000e-04
# Epoch 46/50
# 212/212 [==============================] - 41s 194ms/step - loss: 0.0081 - mae: 0.0659 - val_loss: 0.0133 - val_mae: 0.1053 - lr: 1.0000e-04
# Epoch 47/50
# 212/212 [==============================] - 41s 194ms/step - loss: 0.0085 - mae: 0.0679 - val_loss: 0.0110 - val_mae: 0.0805 - lr: 1.0000e-04
# Epoch 48/50
# 212/212 [==============================] - 41s 193ms/step - loss: 0.0082 - mae: 0.0662 - val_loss: 0.0096 - val_mae: 0.0706 - lr: 1.0000e-04
# Epoch 49/50
# 212/212 [==============================] - ETA: 0s - loss: 0.0082 - mae: 0.0668
# Epoch 49: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 212/212 [==============================] - 41s 194ms/step - loss: 0.0082 - mae: 0.0668 - val_loss: 0.0106 - val_mae: 0.0788 - lr: 1.0000e-04
# Epoch 50/50
# 212/212 [==============================] - 41s 194ms/step - loss: 0.0072 - mae: 0.0610 - val_loss: 0.0090 - val_mae: 0.0764 - lr: 5.0000e-05

# %%
age_model.save_weights("age_weights_2.h5")

# %%
age_model.evaluate(X_test, y_test)
# Out:
# 212/212 [==============================] - 4s 19ms/step - loss: 0.0090 - mae: 0.0764
# [0.008968569338321686, 0.0763947144150734]

# %%
gender=df['gender']
print(gender)
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 33835    1
# 33836    1
# 33837    1
# 33838    1
# 33839    1
# Name: gender, Length: 33840, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, gender, test_size=0.2, random_state=42
)

# %%
def ConvFunc(x, filters=32, kernel_size=(3, 3), dropout_rate=0.1):
    x = Conv2D(filters, kernel_size=kernel_size, padding="same",
               kernel_initializer="he_normal", kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPooling2D()(x)
    x = Dropout(dropout_rate)(x)
    return x
def create_gender_model():
    inputs = Input(shape=(48, 48, 1))

    x = ConvFunc(inputs, 32, dropout_rate=0.1)
    x = ConvFunc(x, 64, dropout_rate=0.15)
    x = ConvFunc(x, 128, dropout_rate=0.2)


    x = Flatten()(x)
    x = Dense(128, activation="relu", kernel_regularizer=l2(0.001))(x)
    x = Dropout(0.4)(x)
    
    outputs = Dense(1, activation="sigmoid")(x)

    model = Model(inputs, outputs)

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0003)

    model.compile(
        optimizer=optimizer,
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model


gender_model = create_gender_model()
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True, verbose=1
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_accuracy", patience=5, verbose=1, factor=0.5, min_lr=1e-5
)

# %%
gender_model.fit(
    X_train, y_train, 
    batch_size=128,
    validation_data=(X_test, y_test),
    epochs=100,
    callbacks=[early_stopping, lr_scheduler],
    verbose=1
)
# Out:
# Epoch 1/100
# 212/212 [==============================] - 8s 34ms/step - loss: 1.3033 - accuracy: 0.6315 - val_loss: 1.2058 - val_accuracy: 0.6782 - lr: 3.0000e-04
# Epoch 2/100
# 212/212 [==============================] - 7s 33ms/step - loss: 1.0927 - accuracy: 0.7180 - val_loss: 0.9971 - val_accuracy: 0.7571 - lr: 3.0000e-04
# Epoch 3/100
# 212/212 [==============================] - 7s 33ms/step - loss: 0.9532 - accuracy: 0.7606 - val_loss: 0.8665 - val_accuracy: 0.7886 - lr: 3.0000e-04
# Epoch 4/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.8542 - accuracy: 0.7791 - val_loss: 0.7771 - val_accuracy: 0.8100 - lr: 3.0000e-04
# Epoch 5/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.7746 - accuracy: 0.7933 - val_loss: 0.7282 - val_accuracy: 0.8057 - lr: 3.0000e-04
# Epoch 6/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.7154 - accuracy: 0.7998 - val_loss: 0.6672 - val_accuracy: 0.8165 - lr: 3.0000e-04
# Epoch 7/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.6640 - accuracy: 0.8097 - val_loss: 0.6173 - val_accuracy: 0.8228 - lr: 3.0000e-04
# Epoch 8/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.6217 - accuracy: 0.8149 - val_loss: 0.5917 - val_accuracy: 0.8299 - lr: 3.0000e-04
# Epoch 9/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.5972 - accuracy: 0.8133 - val_loss: 0.5562 - val_accuracy: 0.8313 - lr: 3.0000e-04
# Epoch 10/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.5625 - accuracy: 0.8228 - val_loss: 0.5365 - val_accuracy: 0.8261 - lr: 3.0000e-04
# Epoch 11/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.5358 - accuracy: 0.8271 - val_loss: 0.5456 - val_accuracy: 0.8091 - lr: 3.0000e-04
# Epoch 12/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.5140 - accuracy: 0.8330 - val_loss: 0.4944 - val_accuracy: 0.8351 - lr: 3.0000e-04
# Epoch 13/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.4978 - accuracy: 0.8338 - val_loss: 0.5316 - val_accuracy: 0.8128 - lr: 3.0000e-04
# Epoch 14/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.4835 - accuracy: 0.8361 - val_loss: 0.4706 - val_accuracy: 0.8363 - lr: 3.0000e-04
# Epoch 15/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.4666 - accuracy: 0.8404 - val_loss: 0.4675 - val_accuracy: 0.8311 - lr: 3.0000e-04
# Epoch 16/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.4586 - accuracy: 0.8434 - val_loss: 0.4489 - val_accuracy: 0.8459 - lr: 3.0000e-04
# Epoch 17/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.4490 - accuracy: 0.8472 - val_loss: 0.4512 - val_accuracy: 0.8348 - lr: 3.0000e-04
# Epoch 18/100
# 212/212 [==============================] - 7s 31ms/step - loss: 0.4380 - accuracy: 0.8457 - val_loss: 0.4499 - val_accuracy: 0.8364 - lr: 3.0000e-04
# Epoch 19/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.4278 - accuracy: 0.8507 - val_loss: 0.4350 - val_accuracy: 0.8491 - lr: 3.0000e-04
# Epoch 20/100
# 212/212 [==============================] - 7s 31ms/step - loss: 0.4197 - accuracy: 0.8512 - val_loss: 0.4266 - val_accuracy: 0.8497 - lr: 3.0000e-04
# Epoch 21/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.4102 - accuracy: 0.8566 - val_loss: 0.4341 - val_accuracy: 0.8496 - lr: 3.0000e-04
# Epoch 22/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.4044 - accuracy: 0.8594 - val_loss: 0.4275 - val_accuracy: 0.8426 - lr: 3.0000e-04
# Epoch 23/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3990 - accuracy: 0.8594 - val_loss: 0.4332 - val_accuracy: 0.8320 - lr: 3.0000e-04
# Epoch 24/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3915 - accuracy: 0.8629 - val_loss: 0.4331 - val_accuracy: 0.8404 - lr: 3.0000e-04
# Epoch 25/100
# 211/212 [============================>.] - ETA: 0s - loss: 0.3864 - accuracy: 0.8657
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3864 - accuracy: 0.8657 - val_loss: 0.4117 - val_accuracy: 0.8468 - lr: 3.0000e-04
# Epoch 26/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3674 - accuracy: 0.8755 - val_loss: 0.4218 - val_accuracy: 0.8418 - lr: 1.5000e-04
# Epoch 27/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3622 - accuracy: 0.8773 - val_loss: 0.4081 - val_accuracy: 0.8522 - lr: 1.5000e-04
# Epoch 28/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3577 - accuracy: 0.8811 - val_loss: 0.4751 - val_accuracy: 0.8274 - lr: 1.5000e-04
# Epoch 29/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3530 - accuracy: 0.8814 - val_loss: 0.4054 - val_accuracy: 0.8568 - lr: 1.5000e-04
# Epoch 30/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3457 - accuracy: 0.8843 - val_loss: 0.4077 - val_accuracy: 0.8562 - lr: 1.5000e-04
# Epoch 31/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3448 - accuracy: 0.8842 - val_loss: 0.4086 - val_accuracy: 0.8576 - lr: 1.5000e-04
# Epoch 32/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3435 - accuracy: 0.8860 - val_loss: 0.4095 - val_accuracy: 0.8542 - lr: 1.5000e-04
# Epoch 33/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3356 - accuracy: 0.8893 - val_loss: 0.4059 - val_accuracy: 0.8567 - lr: 1.5000e-04
# Epoch 34/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3338 - accuracy: 0.8921 - val_loss: 0.4007 - val_accuracy: 0.8568 - lr: 1.5000e-04
# Epoch 35/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3290 - accuracy: 0.8918 - val_loss: 0.3965 - val_accuracy: 0.8580 - lr: 1.5000e-04
# Epoch 36/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3285 - accuracy: 0.8924 - val_loss: 0.4112 - val_accuracy: 0.8468 - lr: 1.5000e-04
# Epoch 37/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3206 - accuracy: 0.8948 - val_loss: 0.3940 - val_accuracy: 0.8573 - lr: 1.5000e-04
# Epoch 38/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3177 - accuracy: 0.8972 - val_loss: 0.3969 - val_accuracy: 0.8585 - lr: 1.5000e-04
# Epoch 39/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3161 - accuracy: 0.8973 - val_loss: 0.4609 - val_accuracy: 0.8248 - lr: 1.5000e-04
# Epoch 40/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3160 - accuracy: 0.8968 - val_loss: 0.3996 - val_accuracy: 0.8589 - lr: 1.5000e-04
# Epoch 41/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3140 - accuracy: 0.8991 - val_loss: 0.4093 - val_accuracy: 0.8589 - lr: 1.5000e-04
# Epoch 42/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3103 - accuracy: 0.9001 - val_loss: 0.4027 - val_accuracy: 0.8555 - lr: 1.5000e-04
# Epoch 43/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3037 - accuracy: 0.9044 - val_loss: 0.3899 - val_accuracy: 0.8621 - lr: 1.5000e-04
# Epoch 44/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3043 - accuracy: 0.9022 - val_loss: 0.4442 - val_accuracy: 0.8317 - lr: 1.5000e-04
# Epoch 45/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.3047 - accuracy: 0.9015 - val_loss: 0.3891 - val_accuracy: 0.8571 - lr: 1.5000e-04
# Epoch 46/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.2974 - accuracy: 0.9057 - val_loss: 0.4178 - val_accuracy: 0.8540 - lr: 1.5000e-04
# Epoch 47/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.2950 - accuracy: 0.9079 - val_loss: 0.3947 - val_accuracy: 0.8553 - lr: 1.5000e-04
# Epoch 48/100
# 211/212 [============================>.] - ETA: 0s - loss: 0.2926 - accuracy: 0.9067
# Epoch 48: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 212/212 [==============================] - 7s 33ms/step - loss: 0.2925 - accuracy: 0.9068 - val_loss: 0.4028 - val_accuracy: 0.8601 - lr: 1.5000e-04
# Epoch 49/100
# 212/212 [==============================] - 7s 33ms/step - loss: 0.2818 - accuracy: 0.9122 - val_loss: 0.4056 - val_accuracy: 0.8595 - lr: 7.5000e-05
# Epoch 50/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.2768 - accuracy: 0.9156 - val_loss: 0.4118 - val_accuracy: 0.8592 - lr: 7.5000e-05
# Epoch 51/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.2777 - accuracy: 0.9154 - val_loss: 0.4095 - val_accuracy: 0.8598 - lr: 7.5000e-05
# Epoch 52/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.2757 - accuracy: 0.9167 - val_loss: 0.4220 - val_accuracy: 0.8582 - lr: 7.5000e-05
# Epoch 53/100
# 211/212 [============================>.] - ETA: 0s - loss: 0.2740 - accuracy: 0.9173
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 212/212 [==============================] - 7s 32ms/step - loss: 0.2740 - accuracy: 0.9174 - val_loss: 0.4000 - val_accuracy: 0.8605 - lr: 7.5000e-05
# Epoch 54/100
# 212/212 [==============================] - 7s 32ms/step - loss: 0.2669 - accuracy: 0.9184 - val_loss: 0.3946 - val_accuracy: 0.8596 - lr: 3.7500e-05
# Epoch 55/100
# 211/212 [============================>.] - ETA: 0s - loss: 0.2625 - accuracy: 0.9244Restoring model weights from the end of the best epoch: 45.
# 212/212 [==============================] - 7s 32ms/step - loss: 0.2626 - accuracy: 0.9243 - val_loss: 0.4045 - val_accuracy: 0.8632 - lr: 3.7500e-05
# Epoch 55: early stopping

# %%
gender_model.save_weights('gender_weights_2.h5')

# %%
from PIL import Image
import numpy as np
import cv2

def preprocess_image(image_path):
    img = Image.open(image_path).convert("L")  # Grayscale
    img = img.resize((48, 48))                 # Resize
    img = np.array(img).astype("float32") / 255.0
    img = img.reshape(1, 48, 48, 1)             # Add batch + channel dims
    return img

# %%
from tensorflow.keras.models import load_model

ethnicity_model = create_ethnicity_model() 
ethnicity_model.load_weights("ethnicity_weights_2.h5")
age_model=create_deep_age_model()
age_model.load_weights("age_weights_2.h5")
gender_model = create_gender_model()
gender_model.load_weights("gender_weights_2.h5")

# %%
def predict_all(image_path):
    img = preprocess_image(image_path)

    predicted_age = age_model.predict(img)[0][0]
    predicted_age = predicted_age * 116
    predicted_gender_prob = gender_model.predict(img)[0][0]
    gender_label = "Female" if predicted_gender_prob > 0.5 else "Male"
    predicted_ethnicity = np.argmax(ethnicity_model.predict(img), axis=1)[0]
    ethnicity_labels = ["White", "Black", "Asian", "Indian", "Other"]
    ethnicity_label = ethnicity_labels[predicted_ethnicity]

    return predicted_age, gender_label, ethnicity_label

# %%
age, gender, ethnicity = predict_all("testimage1.jpg")
print(f"Predicted Age: {age:.1f} years")
print(f"Predicted Gender: {gender}")
print(f"Predicted Ethnicity: {ethnicity}")
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# Predicted Age: 32.0 years
# Predicted Gender: Male
# Predicted Ethnicity: White

# %%
age, gender, ethnicity = predict_all("testimage2.jpg")
print(f"Predicted Age: {age:.1f} years")
print(f"Predicted Gender: {gender}")
print(f"Predicted Ethnicity: {ethnicity}")
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# Predicted Age: 32.0 years
# Predicted Gender: Male
# Predicted Ethnicity: Asian

# %%
age, gender, ethnicity = predict_all("testimage3.jpeg")
print(f"Predicted Age: {age:.1f} years")
print(f"Predicted Gender: {gender}")
print(f"Predicted Ethnicity: {ethnicity}")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Predicted Age: 31.9 years
# Predicted Gender: Female
# Predicted Ethnicity: Indian

# %%
age, gender, ethnicity = predict_all("testimage4.jpg")
print(f"Predicted Age: {age:.1f} years")
print(f"Predicted Gender: {gender}")
print(f"Predicted Ethnicity: {ethnicity}")
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Predicted Age: 31.9 years
# Predicted Gender: Male
# Predicted Ethnicity: Indian

# %%
age, gender, ethnicity = predict_all("testimage5.jpg")
print(f"Predicted Age: {age:.1f} years")
print(f"Predicted Gender: {gender}")
print(f"Predicted Ethnicity: {ethnicity}")
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Predicted Age: 31.9 years
# Predicted Gender: Female
# Predicted Ethnicity: White
